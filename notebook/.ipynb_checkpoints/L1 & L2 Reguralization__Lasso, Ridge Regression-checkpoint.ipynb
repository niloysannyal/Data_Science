# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sn

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Melbourne_housing_Full.csv')
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.shape
# Out:
# (34857, 21)

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df = df[['Suburb','Address','Rooms','Type','Method','SellerG','Distance','Regionname','Propertycount','Bedroom2','Bathroom','Car','Landsize','BuildingArea','Price']]
df.head()
# Out:
#        Suburb             Address  Rooms Type Method SellerG  Distance  \
# 0  Abbotsford       68 Studley St      2    h     SS  Jellis       2.5
# 1  Abbotsford        85 Turner St      2    h      S  Biggin       2.5
# 2  Abbotsford     25 Bloomburg St      2    h      S  Biggin       2.5
# 3  Abbotsford  18/659 Victoria St      3    u     VB  Rounds       2.5
# 4  Abbotsford        5 Charles St      3    h     SP  Biggin       2.5
#
#               Regionname  Propertycount  Bedroom2  Bathroom  Car  Landsize  \
# 0  Northern Metropolitan         4019.0       2.0       1.0  1.0     126.0
# 1  Northern Metropolitan         4019.0       2.0       1.0  1.0     202.0
# 2  Northern Metropolitan         4019.0       2.0       1.0  0.0     156.0
# 3  Northern Metropolitan         4019.0       3.0       2.0  1.0       0.0
# 4  Northern Metropolitan         4019.0       3.0       2.0  0.0     134.0
#
#    BuildingArea      Price
# 0           NaN        NaN
# 1           NaN  1480000.0
# ...

# %%
df.shape
# Out:
# (34857, 15)

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Distance             1
# Regionname           3
# Propertycount        3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
cols_to_fill_zero=['Propertycount','Distance','Bedroom2','Bathroom','Car']
df[cols_to_fill_zero] = df[cols_to_fill_zero].fillna(0)
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Distance             0
# Regionname           3
# Propertycount        0
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
df['Landsize'] = df['Landsize'].fillna(df.Landsize.mean())
df['BuildingArea'] = df['BuildingArea'].fillna(df.BuildingArea.mean())
df.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Distance            0
# Regionname          3
# Propertycount       0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# Price            7610
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Distance         0
# Regionname       0
# Propertycount    0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type Method SellerG  Distance  \
# 1  Abbotsford      85 Turner St      2    h      S  Biggin       2.5
# 2  Abbotsford   25 Bloomburg St      2    h      S  Biggin       2.5
# 4  Abbotsford      5 Charles St      3    h     SP  Biggin       2.5
# 5  Abbotsford  40 Federation La      3    h     PI  Biggin       2.5
# 6  Abbotsford       55a Park St      4    h     VB  Nelson       2.5
#
#               Regionname  Propertycount  Bedroom2  Bathroom  Car  Landsize  \
# 1  Northern Metropolitan         4019.0       2.0       1.0  1.0     202.0
# 2  Northern Metropolitan         4019.0       2.0       1.0  0.0     156.0
# 4  Northern Metropolitan         4019.0       3.0       2.0  0.0     134.0
# 5  Northern Metropolitan         4019.0       3.0       2.0  1.0      94.0
# 6  Northern Metropolitan         4019.0       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price
# 1      160.2564  1480000.0
# 2       79.0000  1035000.0
# ...

# %%
print(df.dtypes.value_counts())
# Out:
# float64    8
# object     6
# int64      1
# dtype: int64

# %%
print(df.select_dtypes(include=['object']).nunique())
# Out:
# Suburb          344
# Address       26748
# Type              3
# Method            5
# SellerG         349
# Regionname        8
# dtype: int64

# %%
low_cardinality_cols = ['Type', 'Method', 'Regionname']
df = pd.get_dummies(df, columns=low_cardinality_cols, drop_first=True)

# %%
high_cardinality_cols = ['Suburb', 'SellerG', 'Address']

for col in high_cardinality_cols:
    df[col] = df[col].map(df[col].value_counts())

# %%
df.shape
# Out:
# (27244, 25)

# %%
df[44:55]
# Out:
#     Suburb  Address  Rooms  SellerG  Distance  Propertycount  Bedroom2  \
# 56     102        1      3      650       2.5         4019.0       3.0
# 57     102        1      1     2735       2.5         4019.0       1.0
# 58     102        1      2     2531       2.5         4019.0       2.0
# 59     102        1      3     2531       2.5         4019.0       3.0
# 61     102        1      2     2735       2.5         4019.0       2.0
# 62     102        1      2      650       2.5         4019.0       0.0
# 63     102        1      2      650       2.5         4019.0       2.0
# 65     102        1      3      650       2.5         4019.0       0.0
# 66     151        1      3     2735      13.5         3464.0       3.0
# 67     151        2      3     2735      13.5         3464.0       3.0
# 68     151        2      3     2735      13.5         3464.0       3.0
#
#     Bathroom  Car    Landsize  ...  Method_SA  Method_SP  Method_VB  \
# ...

# %%
X = df.drop('Price', axis=1)
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R-squared:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 170586427609.09653
# R-squared: 0.570655987973247

# %%
model.score(X_test, y_test)
# Out:
# 0.570655987973247

# %%
model.score(X_train, y_train)
# Out:
# 0.5591171898840851

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=50, max_iter=100, tol=0.1)
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(X_test, y_test)
# Out:
# 0.5706232047718419

# %%
lasso_reg.score(X_train, y_train)
# Out:
# 0.559110616615869

# %%
from sklearn.linear_model import Ridge
Ridge_reg = Ridge(alpha=50, max_iter=100, tol=0.1)
Ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
Ridge_reg.score(X_test, y_test)
# Out:
# 0.570546229057399

# %%
Ridge_reg.score(X_train, y_train)
# Out:
# 0.5587992106340005
