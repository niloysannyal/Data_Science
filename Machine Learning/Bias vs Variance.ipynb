# %% [markdown]
# # Bias = Train error --------------- Variance = Test error

# %% [markdown]
# ## *Types of fitting*

# %% [markdown]
# ![Different_fitting.png](attachment:5b1e376d-443c-45f5-bdff-60572d7951c8.png)

# %% [markdown]
# ## *1. Over fitting*

# %% [markdown]
# ![C.png](attachment:86fe20ad-e5d6-4b20-8695-4fbfa3a07fcc.png)

# %% [markdown]
# <div style="text-align: center;">
#     <h4><em>Fig: High Variance & Zero Bias</em></h4>
# </div>

# %% [markdown]
# ## *2. Under fitting*

# %% [markdown]
# ![D.png](attachment:75e6c7df-b4ef-45c7-b76e-aeb4ddffb398.png)

# %% [markdown]
# <div style="text-align: center;">
#     <h4><em>Fig: Low Variance and High Bias</em></h4>
# </div>

# %% [markdown]
# ## *3. Balance fitting*

# %% [markdown]
# ![E.png](attachment:ae959963-6c16-4fec-a240-b6b864003cc0.png)

# %% [markdown]
# <div style="text-align: center;">
#     <h4><em>Fig: Low Variance and Low Bias</em></h4>
# </div>

# %% [markdown]
# ## *Visual Representation with Bulls Eye*

# %% [markdown]
# ![F.png](attachment:93b66700-76b7-4428-bff6-cb6dd8c8c93a.png)

# %% [markdown]
# ## *Ways to get balanced fit model*
# ### *1. Cross validation*
# - *K Fold Cross Validation*
# ### *2. Regularization*
# - *L1 regularization (Lasso)*
# - *L2 regularization (Ridge)*
# ### *3. Dimensity Reduction*
# - *PCA*
# ### *4. Ensemble Techniques*
# - *Bagging*
# - *Boosting*
